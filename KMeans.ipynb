# %% [markdown]
# ## 1. Import Dataset

# %%
import pandas as pd
import geopandas as gpd
import numpy as np
import folium
import matplotlib.pyplot as plt
from scipy.stats import gmean

# %%
df = pd.read_csv('Netflix Dataset.csv')

# %% [markdown]
# ## 2. Membuat Fungsi K-Means dan Menghitung Cluster Center dari 2 atau 3 cluster

# %%
def euclidean_distance(x1, x2):
    return np.sqrt(np.sum((x1 - x2)**2))

class KMeans:
    def __init__(self, k, max_iters=100):
        self.k = k
        self.centroids = None
        self.max_iters = max_iters

    def fit(self, X):
        n_samples, n_features = X.shape

        geomeans = gmean(np.abs(X[:, 0:2]), axis=1)
        sorted_indices = np.argsort(geomeans)
        X_sorted = X[sorted_indices]

        split_indices = np.array_split(sorted_indices, self.k)
        centroid_indices = [part[len(part) // 2] for part in split_indices]
        self.centroids = X[centroid_indices]

        self.labels = np.zeros((n_samples,))
        for it in range(self.max_iters):
            for i, sample in enumerate(X):
                distances = [euclidean_distance(sample, centroid) for centroid in self.centroids]
                cluster = np.argmin(distances)
                self.labels[i] = cluster

            centroids_old = self.centroids.copy()

            for i in range(self.k):
                points_in_cluster = [X[j] for j in range(n_samples) if self.labels[j] == i]
                if points_in_cluster:
                    self.centroids[i] = np.mean(points_in_cluster, axis=0)

    def predict(self, X):
        return [np.argmin([euclidean_distance(x, centroid) for centroid in self.centroids]) for x in X]

# %%
X = df[['Latitude', 'Longitude', 'Device']].values

# %%
print(X)
# Out:
# [[  39.7837304  -100.445882      2.        ]
#  [  61.0666922  -107.991707      3.        ]
#  [  54.7023545    -3.2765753     1.        ]
#  ...
#  [  33.68495615 -102.80863133    0.        ]
#  [  64.03779427  -72.11359926    3.        ]
#  [  38.86423547 -121.86420511    1.        ]]

# %%
kmeans = KMeans(k=3, max_iters=100)
kmeans.fit(X)
df['Cluster-K3'] = kmeans.labels

# %%
centroids_data = kmeans.centroids
cluster_centers_K2 = pd.DataFrame(centroids_data, columns=['Latitude', 'Longitude', 'Device'])
print("Cluster Centers K2")
print(cluster_centers_K2)
# Out:
# Cluster Centers K2
#     Latitude  Longitude    Device
# 0  35.662511  19.928861  1.466765
# 1  37.237176 -95.392322  1.540140

# %%
print(df)
# Out:
#                        Country  Device   Latitude   Longitude  Cluster-K2
# 0     United States of America       2  39.783730 -100.445882         1.0
# 1                       Canada       3  61.066692 -107.991707         1.0
# 2               United Kingdom       1  54.702354   -3.276575         0.0
# 3                    Australia       0 -24.776109  134.755000         0.0
# 4                      Germany       2  51.163818   10.447831         0.0
# ...                        ...     ...        ...         ...         ...
# 2495                     Spain       1  37.727507   -5.721174         0.0
# 2496                     Spain       1  42.386670   -1.339590         0.0
# 2497  United States of America       0  33.684956 -102.808631         1.0
# 2498                    Canada       3  64.037794  -72.113599         1.0
# 2499  United States of America       1  38.864235 -121.864205         1.0
#
# [2500 rows x 5 columns]

# %%
kmeans = KMeans(k=3, max_iters=100)
kmeans.fit(X)
df['Cluster-K3'] = kmeans.labels

# %%
centroids_data = kmeans.centroids
cluster_centers_K3 = pd.DataFrame(centroids_data, columns=['Latitude', 'Longitude', 'Device'])
print("Cluster Centers K3")
print(cluster_centers_K3)
# Out:
# Cluster Centers K3
#     Latitude   Longitude    Device
# 0  43.795313    0.803132  1.461730
# 1 -25.441349  135.016222  1.513661
# 2  38.542283  -96.869289  1.539910

# %%
print(df[['Device', 'Latitude', 'Longitude', 'Cluster-K2', 'Cluster-K3']])
# Out:
#       Device   Latitude   Longitude  Cluster-K3
# 0          2  39.783730 -100.445882         2.0
# 1          3  61.066692 -107.991707         2.0
# 2          1  54.702354   -3.276575         0.0
# 3          0 -24.776109  134.755000         1.0
# 4          2  51.163818   10.447831         0.0
# ...      ...        ...         ...         ...
# 2495       1  37.727507   -5.721174         0.0
# 2496       1  42.386670   -1.339590         0.0
# 2497       0  33.684956 -102.808631         2.0
# 2498       3  64.037794  -72.113599         2.0
# 2499       1  38.864235 -121.864205         2.0
#
# [2500 rows x 4 columns]

# %% [markdown]
# ## 4. Visualisasi 2 Cluster

# %%
world_geojson = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

map_center = [cluster_centers_K2['Latitude'].mean(), cluster_centers_K2['Longitude'].mean()]
my_map = folium.Map(location=map_center, zoom_start=3)

cluster_colors = {0: 'yellow', 1: 'red'}

folium.Choropleth(
    geo_data='world.json',
    name='choropleth',
    data=df,
    columns=['Country', 'Cluster-K2'],
    key_on='feature.properties.name',
    fill_color='YlOrRd',
    fill_opacity=0.8,
    line_opacity=0.5,
    nan_fill_color='white',
    nan_fill_opacity=0,
    legend_name='Cluster'
).add_to(my_map)

for idx, center in cluster_centers_K2.iterrows():
    cluster_color = cluster_colors[idx % len(cluster_colors)]
    icon = folium.Icon(color='white', icon_color=cluster_color, icon='map-marker', prefix='fa')
    folium.Marker(
        location=[center['Latitude'], center['Longitude']],
        icon=icon,
        popup=f'Cluster {idx}',
    ).add_to(my_map)

folium.LayerControl().add_to(my_map)

my_map
# Out:
# <ipython-input-8-f5b7476d2bbd>:1: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world_geojson = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d7abc187cc056b56d7278894c597762a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d7abc187cc056b56d7278894c597762a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d7abc187cc056b56d7278894c597762a = L.map(
#                 &quot;map_d7abc187cc056b56d7278894c597762a&quot;,
#                 {
#                     center: [36.449843861137225, -37.73173074598194],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 3,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_15f27dd919804a9003231d4857d46f1f = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d7abc187cc056b56d7278894c597762a);
#
#
#             var choropleth_ba8e7a8e46b063285c9c90009664c760 = L.featureGroup(
#                 {}
#             ).addTo(map_d7abc187cc056b56d7278894c597762a);
#
#
#         function geo_json_d2ba91efa8c0b8238cc6f2b8e70a94fc_styler(feature) {
#             switch(feature.properties.name) {
#                 case &quot;Australia&quot;: case &quot;Germany&quot;: case &quot;Spain&quot;: case &quot;France&quot;: case &quot;United Kingdom&quot;: case &quot;Italy&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ffffb2&quot;, &quot;fillOpacity&quot;: 0.8, &quot;opacity&quot;: 0.5, &quot;weight&quot;: 1};
#                 case &quot;Brazil&quot;: case &quot;Canada&quot;: case &quot;Mexico&quot;: case &quot;United States of America&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#bd0026&quot;, &quot;fillOpacity&quot;: 0.8, &quot;opacity&quot;: 0.5, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;white&quot;, &quot;fillOpacity&quot;: 0, &quot;opacity&quot;: 0.5, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_d2ba91efa8c0b8238cc6f2b8e70a94fc_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_d2ba91efa8c0b8238cc6f2b8e70a94fc = L.geoJson(null, {
#                 onEachFeature: geo_json_d2ba91efa8c0b8238cc6f2b8e70a94fc_onEachFeature,
#
#                 style: geo_json_d2ba91efa8c0b8238cc6f2b8e70a94fc_styler,
#         });
#
#         function geo_json_d2ba91efa8c0b8238cc6f2b8e70a94fc_add (data) {
#             geo_json_d2ba91efa8c0b8238cc6f2b8e70a94fc
#                 .addData(data)
#                 .addTo(choropleth_ba8e7a8e46b063285c9c90009664c760);
#         }
#             geo_json_d2ba91efa8c0b8238cc6f2b8e70a94fc_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[61.210817, 35.650072], [62.230651, 35.270664], [62.984662, 35.404041], [63.193538, 35.857166], [63.982896, 36.007957], [64.546479, 36.312073], [64.746105, 37.111818], [65.588948, 37.305217], [65.745631, 37.661164], [66.217385, 37.39379], [66.518607, 37.362784], [67.075782, 37.356144], [67.83, 37.144994], [68.135562, 37.023115], [68.859446, 37.344336], [69.196273, 37.151144], [69.518785, 37.608997], [70.116578, 37.588223], [70.270574, 37.735165], [70.376304, 38.138396], [70.806821, 38.486282], [71.348131, 38.258905], [71.239404, 37.953265], [71.541918, 37.905774], [71.448693, 37.065645], [71.844638, 36.738171], [72.193041, 36.948288], [72.63689, 37.047558], [73.260056, 37.495257], [73.948696, 37.421566], [74.980002, 37.41999], [75.158028, 37.133031], [74.575893, 37.020841], [74.067552, 36.836176], [72.920025, 36.720007], [71.846292, 36.509942], [71.262348, 36.074388], [71.498768, 35.650563], [71.613076, 35.153203], [71.115019, 34.733126], [71.156773, 34.348911], [70.881803, 33.988856], [69.930543, 34.02012], [70.323594, 33.358533], [69.687147, 33.105499], [69.262522, 32.501944], [69.317764, 31.901412], [68.926677, 31.620189], [68.556932, 31.71331], [67.792689, 31.58293], [67.683394, 31.303154], [66.938891, 31.304911], [66.381458, 30.738899], [66.346473, 29.887943], [65.046862, 29.472181], [64.350419, 29.560031], [64.148002, 29.340819], [63.550261, 29.468331], [62.549857, 29.318572], [60.874248, 29.829239], [61.781222, 30.73585], [61.699314, 31.379506], [60.941945, 31.548075], [60.863655, 32.18292], [60.536078, 32.981269], [60.9637, 33.528832], [60.52843, 33.676446], [60.803193, 34.404102], [61.210817, 35.650072]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;AFG&quot;, &quot;properties&quot;: {&quot;name&quot;: &quot;Afghanistan&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[[16.326528, -5.87747], [16.57318, -6.622645], [16.860191, -7.222298], [17.089996, -7.54568

# %%
world_geojson = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

map_center = [cluster_centers_K2['Latitude'].mean(), cluster_centers_K2['Longitude'].mean()]
my_map = folium.Map(location=map_center, zoom_start=3)

cluster_colors = {0: 'yellow', 1: 'red'}

folium.Choropleth(
    geo_data='world.json',
    name='choropleth',
    data=df,
    columns=['Country', 'Cluster-K2'],
    key_on='feature.properties.name',
    fill_color='YlOrRd',
    fill_opacity=0.8,
    line_opacity=0.5,
    nan_fill_color='white',
    nan_fill_opacity=0,
    legend_name='Cluster'
).add_to(my_map)

for idx, center in cluster_centers_K2.iterrows():
    cluster_color = cluster_colors[idx % len(cluster_colors)]
    icon = folium.Icon(color='white', icon_color=cluster_color, icon='map-marker', prefix='fa')
    folium.Marker(
        location=[center['Latitude'], center['Longitude']],
        icon=icon,
        popup=f'Cluster {idx}',
    ).add_to(my_map)

for i in range(len(cluster_centers_K2) - 1):
    point1 = cluster_centers_K2.iloc[i]
    point2 = cluster_centers_K2.iloc[i + 1]
    folium.PolyLine(
        locations=[[point1['Latitude'], point1['Longitude']], [point2['Latitude'], point2['Longitude']]],
        color='black',
        weight=2,
        dash_array='5, 5'
    ).add_to(my_map)

folium.LayerControl().add_to(my_map)

my_map
# Out:
# <ipython-input-9-186490adf170>:1: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world_geojson = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9f7916fb4984f7e9c47188718f109e2a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9f7916fb4984f7e9c47188718f109e2a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9f7916fb4984f7e9c47188718f109e2a = L.map(
#                 &quot;map_9f7916fb4984f7e9c47188718f109e2a&quot;,
#                 {
#                     center: [36.449843861137225, -37.73173074598194],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 3,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2b41e18a37c925cb5abae5c0b049de77 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9f7916fb4984f7e9c47188718f109e2a);
#
#
#             var choropleth_d1b4bccf489582d8660a43f8a1231f53 = L.featureGroup(
#                 {}
#             ).addTo(map_9f7916fb4984f7e9c47188718f109e2a);
#
#
#         function geo_json_bdae2856e56c0b6abc75e959a073b6b4_styler(feature) {
#             switch(feature.properties.name) {
#                 case &quot;Australia&quot;: case &quot;Germany&quot;: case &quot;Spain&quot;: case &quot;France&quot;: case &quot;United Kingdom&quot;: case &quot;Italy&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ffffb2&quot;, &quot;fillOpacity&quot;: 0.8, &quot;opacity&quot;: 0.5, &quot;weight&quot;: 1};
#                 case &quot;Brazil&quot;: case &quot;Canada&quot;: case &quot;Mexico&quot;: case &quot;United States of America&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#bd0026&quot;, &quot;fillOpacity&quot;: 0.8, &quot;opacity&quot;: 0.5, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;white&quot;, &quot;fillOpacity&quot;: 0, &quot;opacity&quot;: 0.5, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_bdae2856e56c0b6abc75e959a073b6b4_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_bdae2856e56c0b6abc75e959a073b6b4 = L.geoJson(null, {
#                 onEachFeature: geo_json_bdae2856e56c0b6abc75e959a073b6b4_onEachFeature,
#
#                 style: geo_json_bdae2856e56c0b6abc75e959a073b6b4_styler,
#         });
#
#         function geo_json_bdae2856e56c0b6abc75e959a073b6b4_add (data) {
#             geo_json_bdae2856e56c0b6abc75e959a073b6b4
#                 .addData(data)
#                 .addTo(choropleth_d1b4bccf489582d8660a43f8a1231f53);
#         }
#             geo_json_bdae2856e56c0b6abc75e959a073b6b4_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[61.210817, 35.650072], [62.230651, 35.270664], [62.984662, 35.404041], [63.193538, 35.857166], [63.982896, 36.007957], [64.546479, 36.312073], [64.746105, 37.111818], [65.588948, 37.305217], [65.745631, 37.661164], [66.217385, 37.39379], [66.518607, 37.362784], [67.075782, 37.356144], [67.83, 37.144994], [68.135562, 37.023115], [68.859446, 37.344336], [69.196273, 37.151144], [69.518785, 37.608997], [70.116578, 37.588223], [70.270574, 37.735165], [70.376304, 38.138396], [70.806821, 38.486282], [71.348131, 38.258905], [71.239404, 37.953265], [71.541918, 37.905774], [71.448693, 37.065645], [71.844638, 36.738171], [72.193041, 36.948288], [72.63689, 37.047558], [73.260056, 37.495257], [73.948696, 37.421566], [74.980002, 37.41999], [75.158028, 37.133031], [74.575893, 37.020841], [74.067552, 36.836176], [72.920025, 36.720007], [71.846292, 36.509942], [71.262348, 36.074388], [71.498768, 35.650563], [71.613076, 35.153203], [71.115019, 34.733126], [71.156773, 34.348911], [70.881803, 33.988856], [69.930543, 34.02012], [70.323594, 33.358533], [69.687147, 33.105499], [69.262522, 32.501944], [69.317764, 31.901412], [68.926677, 31.620189], [68.556932, 31.71331], [67.792689, 31.58293], [67.683394, 31.303154], [66.938891, 31.304911], [66.381458, 30.738899], [66.346473, 29.887943], [65.046862, 29.472181], [64.350419, 29.560031], [64.148002, 29.340819], [63.550261, 29.468331], [62.549857, 29.318572], [60.874248, 29.829239], [61.781222, 30.73585], [61.699314, 31.379506], [60.941945, 31.548075], [60.863655, 32.18292], [60.536078, 32.981269], [60.9637, 33.528832], [60.52843, 33.676446], [60.803193, 34.404102], [61.210817, 35.650072]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;AFG&quot;, &quot;properties&quot;: {&quot;name&quot;: &quot;Afghanistan&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[[16.326528, -5.87747], [16.57318, -6.622645], [16.860191, -7.222298], [17.089996, -7.54568

# %%
world_geojson = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

map_center = [cluster_centers_K2['Latitude'].mean(), cluster_centers_K2['Longitude'].mean()]
my_map = folium.Map(location=map_center, zoom_start=3)

cluster_colors = {0: 'yellow', 1: 'red'}

folium.Choropleth(
    geo_data='world.json',
    name='choropleth',
    data=df,
    columns=['Country', 'Cluster-K2'],
    key_on='feature.properties.name',
    fill_color='YlOrRd',
    fill_opacity=0.8,
    line_opacity=0.5,
    nan_fill_color='white',
    nan_fill_opacity=0,
    legend_name='Cluster'
).add_to(my_map)

for idx, center in cluster_centers_K2.iterrows():
    cluster_color = cluster_colors[idx % len(cluster_colors)]
    icon = folium.Icon(color='white', icon_color=cluster_color, icon='map-marker', prefix='fa')
    folium.Marker(
        location=[center['Latitude'], center['Longitude']],
        icon=icon,
        popup=f'Cluster {idx}',
    ).add_to(my_map)

for i in range(len(cluster_centers_K2) - 1):
    point1 = cluster_centers_K2.iloc[i]
    point2 = cluster_centers_K2.iloc[i + 1]
    folium.PolyLine(
        locations=[[point1['Latitude'], point1['Longitude']], [point2['Latitude'], point2['Longitude']]],
        color='black',
        weight=2,
        dash_array='5, 5'
    ).add_to(my_map)

folium.LayerControl().add_to(my_map)

my_map
# Out:
# <ipython-input-10-186490adf170>:1: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world_geojson = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e329aa48e364be8ac9598307811cb2ce {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e329aa48e364be8ac9598307811cb2ce&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e329aa48e364be8ac9598307811cb2ce = L.map(
#                 &quot;map_e329aa48e364be8ac9598307811cb2ce&quot;,
#                 {
#                     center: [36.449843861137225, -37.73173074598194],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 3,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7920cdb57c13e74ea4834bfe728012fe = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e329aa48e364be8ac9598307811cb2ce);
#
#
#             var choropleth_767829f4689a8e3c4e2a6479091017b9 = L.featureGroup(
#                 {}
#             ).addTo(map_e329aa48e364be8ac9598307811cb2ce);
#
#
#         function geo_json_01f4b85f57566e01ed28ed15d4230448_styler(feature) {
#             switch(feature.properties.name) {
#                 case &quot;Australia&quot;: case &quot;Germany&quot;: case &quot;Spain&quot;: case &quot;France&quot;: case &quot;United Kingdom&quot;: case &quot;Italy&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ffffb2&quot;, &quot;fillOpacity&quot;: 0.8, &quot;opacity&quot;: 0.5, &quot;weight&quot;: 1};
#                 case &quot;Brazil&quot;: case &quot;Canada&quot;: case &quot;Mexico&quot;: case &quot;United States of America&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#bd0026&quot;, &quot;fillOpacity&quot;: 0.8, &quot;opacity&quot;: 0.5, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;white&quot;, &quot;fillOpacity&quot;: 0, &quot;opacity&quot;: 0.5, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_01f4b85f57566e01ed28ed15d4230448_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_01f4b85f57566e01ed28ed15d4230448 = L.geoJson(null, {
#                 onEachFeature: geo_json_01f4b85f57566e01ed28ed15d4230448_onEachFeature,
#
#                 style: geo_json_01f4b85f57566e01ed28ed15d4230448_styler,
#         });
#
#         function geo_json_01f4b85f57566e01ed28ed15d4230448_add (data) {
#             geo_json_01f4b85f57566e01ed28ed15d4230448
#                 .addData(data)
#                 .addTo(choropleth_767829f4689a8e3c4e2a6479091017b9);
#         }
#             geo_json_01f4b85f57566e01ed28ed15d4230448_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[61.210817, 35.650072], [62.230651, 35.270664], [62.984662, 35.404041], [63.193538, 35.857166], [63.982896, 36.007957], [64.546479, 36.312073], [64.746105, 37.111818], [65.588948, 37.305217], [65.745631, 37.661164], [66.217385, 37.39379], [66.518607, 37.362784], [67.075782, 37.356144], [67.83, 37.144994], [68.135562, 37.023115], [68.859446, 37.344336], [69.196273, 37.151144], [69.518785, 37.608997], [70.116578, 37.588223], [70.270574, 37.735165], [70.376304, 38.138396], [70.806821, 38.486282], [71.348131, 38.258905], [71.239404, 37.953265], [71.541918, 37.905774], [71.448693, 37.065645], [71.844638, 36.738171], [72.193041, 36.948288], [72.63689, 37.047558], [73.260056, 37.495257], [73.948696, 37.421566], [74.980002, 37.41999], [75.158028, 37.133031], [74.575893, 37.020841], [74.067552, 36.836176], [72.920025, 36.720007], [71.846292, 36.509942], [71.262348, 36.074388], [71.498768, 35.650563], [71.613076, 35.153203], [71.115019, 34.733126], [71.156773, 34.348911], [70.881803, 33.988856], [69.930543, 34.02012], [70.323594, 33.358533], [69.687147, 33.105499], [69.262522, 32.501944], [69.317764, 31.901412], [68.926677, 31.620189], [68.556932, 31.71331], [67.792689, 31.58293], [67.683394, 31.303154], [66.938891, 31.304911], [66.381458, 30.738899], [66.346473, 29.887943], [65.046862, 29.472181], [64.350419, 29.560031], [64.148002, 29.340819], [63.550261, 29.468331], [62.549857, 29.318572], [60.874248, 29.829239], [61.781222, 30.73585], [61.699314, 31.379506], [60.941945, 31.548075], [60.863655, 32.18292], [60.536078, 32.981269], [60.9637, 33.528832], [60.52843, 33.676446], [60.803193, 34.404102], [61.210817, 35.650072]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;AFG&quot;, &quot;properties&quot;: {&quot;name&quot;: &quot;Afghanistan&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[[16.326528, -5.87747], [16.57318, -6.622645], [16.860191, -7.222298], [17.089996, -7.54568

# %%
from shapely.geometry import MultiPoint, Point
import geopandas as gpd

cluster_polygons = []

for cluster_id, cluster_data in df.groupby('Cluster-K2'):
    points = MultiPoint(cluster_data[['Longitude', 'Latitude']].values)
    buffer = points.buffer(0.1)
    cluster_polygon = buffer.convex_hull
    cluster_polygons.append({'Cluster-K2': cluster_id, 'geometry': cluster_polygon})

cluster_polygons_gdf = gpd.GeoDataFrame(cluster_polygons)

cluster_polygons_gdf.set_crs(epsg=4326, inplace=True)

cluster_centers = df.groupby('Cluster-K2').agg({'Latitude': 'mean', 'Longitude': 'mean'})
map_center = [df['Latitude'].mean(), df['Longitude'].mean()]
my_map = folium.Map(location=map_center, zoom_start=3)

cluster_colors = {0: 'yellow', 1: 'red'}

for idx, center in cluster_centers_K2.iterrows():
    cluster_color = cluster_colors[idx % len(cluster_colors)]
    icon = folium.Icon(color='white', icon_color=cluster_color, icon='map-marker', prefix='fa')
    folium.Marker(
        location=[center['Latitude'], center['Longitude']],
        icon=icon,
        popup=f'Cluster {idx}',
    ).add_to(my_map)


for cluster_id, cluster_data in cluster_polygons_gdf.iterrows():
    cluster_color = cluster_colors[cluster_data['Cluster-K2']]
    folium.GeoJson(
        cluster_data['geometry'],
        style_function=lambda feature, color=cluster_color: {
            'fillColor': color,
            'color': 'black',
            'weight': 2,
            'fillOpacity': 0.5,
        }
    ).add_to(my_map)

for i in range(len(cluster_centers_K2)):
    for j in range(i + 1, len(cluster_centers_K2)):
        point1 = cluster_centers_K2.iloc[i]
        point2 = cluster_centers_K2.iloc[j]
        folium.PolyLine(
            locations=[[point1['Latitude'], point1['Longitude']], [point2['Latitude'], point2['Longitude']]],
            color='black',
            weight=2,
            dash_array='5, 5'
        ).add_to(my_map)

my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_74fa81d03cce68306854891a9599b6d4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_74fa81d03cce68306854891a9599b6d4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_74fa81d03cce68306854891a9599b6d4 = L.map(
#                 &quot;map_74fa81d03cce68306854891a9599b6d4&quot;,
#                 {
#                     center: [36.38433780236406, -32.93436955375282],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 3,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_64e7efcf1114a24bf973cff857bcddf9 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_74fa81d03cce68306854891a9599b6d4);
#
#
#             var marker_9a4e0a67fa7644ec2d19eda1ffe0b8d2 = L.marker(
#                 [35.66251142395948, 19.92886050677119],
#                 {}
#             ).addTo(map_74fa81d03cce68306854891a9599b6d4);
#
#
#             var icon_7bfe5d0bc22dd11f9716d8278828636e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;map-marker&quot;, &quot;iconColor&quot;: &quot;yellow&quot;, &quot;markerColor&quot;: &quot;white&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_9a4e0a67fa7644ec2d19eda1ffe0b8d2.setIcon(icon_7bfe5d0bc22dd11f9716d8278828636e);
#
#
#         var popup_e3dd415dfae07753887ca0b561c3adb2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e040e784b255317babfcf3c83622ca22 = $(`&lt;div id=&quot;html_e040e784b255317babfcf3c83622ca22&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cluster 0&lt;/div&gt;`)[0];
#                 popup_e3dd415dfae07753887ca0b561c3adb2.setContent(html_e040e784b255317babfcf3c83622ca22);
#
#
#
#         marker_9a4e0a67fa7644ec2d19eda1ffe0b8d2.bindPopup(popup_e3dd415dfae07753887ca0b561c3adb2)
#         ;
#
#
#
#
#             var marker_6114723ea36d7afaaf525f6b3c385cc4 = L.marker(
#                 [37.23717629831497, -95.39232199873507],
#                 {}
#             ).addTo(map_74fa81d03cce68306854891a9599b6d4);
#
#
#             var icon_74d6484a4ef1460db4ffc40febd6c3cd = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;map-marker&quot;, &quot;iconColor&quot;: &quot;red&quot;, &quot;markerColor&quot;: &quot;white&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_6114723ea36d7afaaf525f6b3c385cc4.setIcon(icon_74d6484a4ef1460db4ffc40febd6c3cd);
#
#
#         var popup_e4d111ce6dcfccfaa09b955987044df0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e7f8e1ec100cb6702719b92dfc91dfdb = $(`&lt;div id=&quot;html_e7f8e1ec100cb6702719b92dfc91dfdb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cluster 1&lt;/div&gt;`)[0];
#                 popup_e4d111ce6dcfccfaa09b955987044df0.setContent(html_e7f8e1ec100cb6702719b92dfc91dfdb);
#
#
#
#         marker_6114723ea36d7afaaf525f6b3c385cc4.bindPopup(popup_e4d111ce6dcfccfaa09b955987044df0)
#         ;
#
#
#
#
#         function geo_json_b6a7870596941c14285bbbcbdb3e1e5d_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;yellow&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#
#         function geo_json_b6a7870596941c14285bbbcbdb3e1e5d_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_b6a7870596941c14285bbbcbdb3e1e5d = L.geoJson(null, {
#                 onEachFeature: geo_json_b6a7870596941c14285bbbcbdb3e1e5d_onEachFeature,
#
#                 style: geo_json_b6a7870596941c14285bbbcbdb3e1e5d_styler,
#         });
#
#         function geo_json_b6a7870596941c14285bbbcbdb3e1e5d_add (data) {
#             geo_json_b6a7870596941c14285bbbcbdb3e1e5d
#                 .addData(data)
#                 .addTo(map_74fa81d03cce68306854891a9599b6d4);
#         }
#             geo_json_b6a7870596941c14285bbbcbdb3e1e5d_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[146.004858962294, -42.53739339934529], [145.99505724826105, -42.53691187201251], [145.98534993009238, -42.535471927385615], [-37.69138816805406, -10.007743417218064], [-37.700907603577896, -10.005358922750961], [-37.71014747908896, -10.002052842428869], [-37.71901880953505, -9.997857015612576], [-37.72743615915441, -9.992811850407994], [-37.735318464268815, -9.986965934514014], [-37.74258981397111, -9.980375567296395], [-37.74918018118873, -9.973104217594106], [-37.755026097082705, -9.96

# %%
from shapely.geometry import Point, Polygon, MultiPoint, LineString
import math

world_geojson = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

square_bounds = [-180, -90, 180, 90]
square_polygon = Polygon([
    (square_bounds[0], square_bounds[1]),
    (square_bounds[0], square_bounds[3]),
    (square_bounds[2], square_bounds[3]),
    (square_bounds[2], square_bounds[1]),
    (square_bounds[0], square_bounds[1])
])

center_lat = (square_bounds[1] + square_bounds[3]) / 2
center_lon = (square_bounds[0] + square_bounds[2]) / 2
center_point = (center_lat, center_lon)

division_line = LineString([(center_lon, square_bounds[1]), (center_lon, square_bounds[3])])

left_polygon = Polygon([
    (square_bounds[0], square_bounds[1]),
    (square_bounds[0], square_bounds[3]),
    (center_lon, square_bounds[3]),
    (center_lon, square_bounds[1]),
    (square_bounds[0], square_bounds[1])
])

right_polygon = Polygon([
    (center_lon, square_bounds[1]),
    (center_lon, square_bounds[3]),
    (square_bounds[2], square_bounds[3]),
    (square_bounds[2], square_bounds[1]),
    (center_lon, square_bounds[1])
])

left_centroid = left_polygon.centroid.coords[0][::-1]
right_centroid = right_polygon.centroid.coords[0][::-1]

my_map = folium.Map(location=[0, 0], zoom_start=2)

cluster_polygons = []

for cluster_id, cluster_data in df.groupby('Cluster-K2'):
    points = MultiPoint(cluster_data[['Longitude', 'Latitude']].values)
    buffer = points.buffer(0.1)
    cluster_polygon = buffer.convex_hull
    cluster_polygons.append({'Cluster-K2': cluster_id, 'geometry': cluster_polygon})

cluster_polygons_gdf = gpd.GeoDataFrame(cluster_polygons)
cluster_polygons_gdf.set_crs(epsg=4326, inplace=True)

cluster_centers = df.groupby('Cluster-K2').agg({'Latitude': 'mean', 'Longitude': 'mean'})
map_center = [df['Latitude'].mean(), df['Longitude'].mean()]
my_map = folium.Map(location=map_center, zoom_start=3)

cluster_colors = {0: 'yellow', 1: 'orange'}

for idx, center in cluster_centers_K2.iterrows():
    cluster_color = cluster_colors[idx % len(cluster_colors)]
    icon = folium.Icon(color='white', icon_color=cluster_color, icon='map-marker', prefix='fa')
    folium.Marker(
        location=[center['Latitude'], center['Longitude']],
        icon=icon,
        popup=f'Cluster {idx}',
    ).add_to(my_map)

for cluster_id, cluster_data in cluster_polygons_gdf.iterrows():
    cluster_color = cluster_colors[cluster_data['Cluster-K2']]
    folium.GeoJson(
        cluster_data['geometry'],
        style_function=lambda feature, color=cluster_color: {
            'fillColor': color,
            'color': 'black',
            'weight': 2,
            'fillOpacity': 0.5,
        }
    ).add_to(my_map)

for i in range(len(cluster_centers_K2)):
    for j in range(i + 1, len(cluster_centers_K2)):
        point1 = cluster_centers_K2.iloc[i]
        point2 = cluster_centers_K2.iloc[j]
        folium.PolyLine(
            locations=[[point1['Latitude'], point1['Longitude']], [point2['Latitude'], point2['Longitude']]],
            color='black',
            weight=2,
            dash_array='5, 5'
        ).add_to(my_map)

folium.GeoJson(
    square_polygon,
    style_function=lambda feature: {
        'fillColor': 'transparent',
        'color': 'blue',
        'weight': 2
    }
).add_to(my_map)

folium.Marker(
    location=center_point,
    icon=folium.Icon(color='black', icon='info-sign'),
    popup='Center Point'
).add_to(my_map)

folium.PolyLine(
    locations=[(square_bounds[1], center_lon), (square_bounds[3], center_lon)],
    color="black"
).add_to(my_map)

folium.GeoJson(
    left_polygon,
    style_function=lambda feature: {
        'fillColor': 'transparent',
        'color': 'black',
        'weight': 2
    }
).add_to(my_map)

folium.GeoJson(
    right_polygon,
    style_function=lambda feature: {
        'fillColor': 'transparent',
        'color': 'black',
        'weight': 2
    }
).add_to(my_map)

folium.Marker(
    location=left_centroid,
    icon = folium.Icon(color='white', icon_color='orange', icon='map-marker', prefix='fa'),
    popup='Centroid 1'
).add_to(my_map)


folium.Marker(
    location=right_centroid,
    icon = folium.Icon(color='white', icon_color='yellow', icon='map-marker', prefix='fa'),
    popup='Right Centroid'
).add_to(my_map)

centroids_data = {
    'Latitude': [left_centroid[0], right_centroid[0]],
    'Longitude': [left_centroid[1], right_centroid[1]]
}

centers_k2 = pd.DataFrame(centroids_data)

my_map
# Out:
# <ipython-input-16-2555f5a058bf>:5: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world_geojson = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_11e6046b09e12cde6193323a5483fc11 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_11e6046b09e12cde6193323a5483fc11&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_11e6046b09e12cde6193323a5483fc11 = L.map(
#                 &quot;map_11e6046b09e12cde6193323a5483fc11&quot;,
#                 {
#                     center: [36.38433780236406, -32.93436955375282],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 3,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_05c68bc6e547daf49ff8270763b35011 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_11e6046b09e12cde6193323a5483fc11);
#
#
#             var marker_6f7f53c7fd116374d9c93e5978b46b0a = L.marker(
#                 [35.66251142395948, 19.92886050677119],
#                 {}
#             ).addTo(map_11e6046b09e12cde6193323a5483fc11);
#
#
#             var icon_759b54e5f3d7f1b4bcca37507b20095d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;map-marker&quot;, &quot;iconColor&quot;: &quot;yellow&quot;, &quot;markerColor&quot;: &quot;white&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_6f7f53c7fd116374d9c93e5978b46b0a.setIcon(icon_759b54e5f3d7f1b4bcca37507b20095d);
#
#
#         var popup_2d719be773a6bce972151c681abbf363 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2ed57077fbdeaef0def71078ef156b5b = $(`&lt;div id=&quot;html_2ed57077fbdeaef0def71078ef156b5b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cluster 0&lt;/div&gt;`)[0];
#                 popup_2d719be773a6bce972151c681abbf363.setContent(html_2ed57077fbdeaef0def71078ef156b5b);
#
#
#
#         marker_6f7f53c7fd116374d9c93e5978b46b0a.bindPopup(popup_2d719be773a6bce972151c681abbf363)
#         ;
#
#
#
#
#             var marker_48e9be7b7814a20b2388775969b7ce32 = L.marker(
#                 [37.23717629831497, -95.39232199873507],
#                 {}
#             ).addTo(map_11e6046b09e12cde6193323a5483fc11);
#
#
#             var icon_1bdb983bf3a75879a933b325e6026fb6 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;map-marker&quot;, &quot;iconColor&quot;: &quot;orange&quot;, &quot;markerColor&quot;: &quot;white&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_48e9be7b7814a20b2388775969b7ce32.setIcon(icon_1bdb983bf3a75879a933b325e6026fb6);
#
#
#         var popup_7a78b8f224dbac31181f94a85c97493f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5d80f0aa38c91c83f95c3d56c5158645 = $(`&lt;div id=&quot;html_5d80f0aa38c91c83f95c3d56c5158645&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cluster 1&lt;/div&gt;`)[0];
#                 popup_7a78b8f224dbac31181f94a85c97493f.setContent(html_5d80f0aa38c91c83f95c3d56c5158645);
#
#
#
#         marker_48e9be7b7814a20b2388775969b7ce32.bindPopup(popup_7a78b8f224dbac31181f94a85c97493f)
#         ;
#
#
#
#
#         function geo_json_d3cd17ace13b5418d0aae9891b30e0e4_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;yellow&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#
#         function geo_json_d3cd17ace13b5418d0aae9891b30e0e4_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_d3cd17ace13b5418d0aae9891b30e0e4 = L.geoJson(null, {
#                 onEachFeature: geo_json_d3cd17ace13b5418d0aae9891b30e0e4_onEachFeature,
#
#                 style: geo_json_d3cd17ace13b5418d0aae9891b30e0e4_styler,
#         });
#
#         function geo_json_d3cd17ace13b5418d0aae9891b30e0e4_add (data) {
#             geo_json_d3cd17ace13b5418d0aae9891b30e0e4
#                 .addData(data)
#                 .addTo(map_11e6046b09e12cde6193323a5483fc11);
#         }
#             geo_json_d3cd17ace13b5418d0aae9891b30e0e4_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[146.004858962294, -42.53739339934529], [145.99505724826105, -42.53691187201251], [145.98534993009238, -42.535471927385615], [-37.69138816805406, -10.007743417218064], [-37.700907603577896, -10.005358922750961], [-37.71014747908896, -10.002052842428869], [-37.71901880953505, -9.997857015612576], [-37.72743615915441, -9.992811850407994], [-37.735318464268815, -9.986965934514014], [-37.74258981397111, -9.980375567296395], [-37.74918018118873, -9.973104217594106], [-37.755026097082705, -9

# %%
import geopandas as gpd
import folium
from shapely.geometry import Point, Polygon, MultiPoint

world_geojson = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

left_polygon = Polygon([
    (square_bounds[0], square_bounds[1]),
    (square_bounds[0], square_bounds[3]),
    (center_lon, square_bounds[3]),
    (center_lon, square_bounds[1]),
    (square_bounds[0], square_bounds[1])
])

right_polygon = Polygon([
    (center_lon, square_bounds[1]),
    (center_lon, square_bounds[3]),
    (square_bounds[2], square_bounds[3]),
    (square_bounds[2], square_bounds[1]),
    (center_lon, square_bounds[1])
])

left_centroid = left_polygon.centroid.coords[0][::-1]
right_centroid = right_polygon.centroid.coords[0][::-1]

my_map = folium.Map(location=[0, 0], zoom_start=2)
cluster_polygons = []

for cluster_id, cluster_data in df.groupby('Cluster-K2'):
    points = MultiPoint(cluster_data[['Longitude', 'Latitude']].values)
    buffer = points.buffer(0.1)
    cluster_polygon = buffer.convex_hull
    cluster_polygons.append({'Cluster-K2': cluster_id, 'geometry': cluster_polygon})

cluster_polygons_gdf = gpd.GeoDataFrame(cluster_polygons)
cluster_polygons_gdf.set_crs(epsg=4326, inplace=True)

cluster_centers = df.groupby('Cluster-K2').agg({'Latitude': 'mean', 'Longitude': 'mean'})
map_center = [df['Latitude'].mean(), df['Longitude'].mean()]
my_map = folium.Map(location=map_center, zoom_start=3)

cluster_colors = {0: 'green', 1: 'orange'}

for idx, center in cluster_centers.iterrows():
    cluster_color = cluster_colors[idx % len(cluster_colors)]
    icon = folium.Icon(color='white', icon_color=cluster_color, icon='map-marker', prefix='fa')
    folium.Marker(
        location=[center['Latitude'], center['Longitude']],
        icon=icon,
        popup=f'Cluster {idx}',
    ).add_to(my_map)

for cluster_id, cluster_data in cluster_polygons_gdf.iterrows():
    cluster_color = cluster_colors[cluster_data['Cluster-K2']]
    folium.GeoJson(
        cluster_data['geometry'],
        style_function=lambda feature, color=cluster_color: {
            'fillColor': color,
            'color': 'black',
            'weight': 2,
            'fillOpacity': 0.5,
        }
    ).add_to(my_map)

square_polygon = Polygon([
    (square_bounds[0], square_bounds[1]),
    (square_bounds[0], square_bounds[3]),
    (square_bounds[2], square_bounds[3]),
    (square_bounds[2], square_bounds[1]),
    (square_bounds[0], square_bounds[1])
])
folium.GeoJson(
    square_polygon,
    style_function=lambda feature: {
        'fillColor': 'transparent',
        'color': 'blue',
        'weight': 2
    }
).add_to(my_map)

center_point = [sum(x)/2 for x in zip(*[square_polygon.exterior.coords[0], square_polygon.exterior.coords[2]])]
folium.Marker(
    location=center_point,
    icon=folium.Icon(color='black', icon='info-sign'),
    popup='Center Point'
).add_to(my_map)

folium.PolyLine(
    locations=[(square_bounds[1], center_lon), (square_bounds[3], center_lon)],
    color="black"
).add_to(my_map)

for polygon, color in [(left_polygon, 'black'), (right_polygon, 'black')]:
    folium.GeoJson(
        polygon,
        style_function=lambda feature, color=color: {
            'fillColor': 'transparent',
            'color': color,
            'weight': 2
        }
    ).add_to(my_map)

for centroid, color, label in [(left_centroid, 'orange', 'Centroid 1'), (right_centroid, 'green', 'Centroid 2')]:
    folium.Marker(
        location=centroid,
        icon=folium.Icon(color=color, icon='info-sign'),
        popup=label
    ).add_to(my_map)

point1 = cluster_centers_K2.iloc[0]
point2 = cluster_centers_K2.iloc[1]
folium.PolyLine(
    locations=[left_centroid, [point2['Latitude'], point2['Longitude']]],
    color='blue',
    weight=2,
    dash_array='5, 5'
).add_to(my_map)

folium.PolyLine(
    locations=[right_centroid, [point1['Latitude'], point1['Longitude']]],
    color='blue',
    weight=2,
    dash_array='5, 5'
).add_to(my_map)

my_map
# Out:
# <ipython-input-53-2b138e93d774>:6: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world_geojson = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d436d77f679909e308e8f44394bb3934 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d436d77f679909e308e8f44394bb3934&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d436d77f679909e308e8f44394bb3934 = L.map(
#                 &quot;map_d436d77f679909e308e8f44394bb3934&quot;,
#                 {
#                     center: [36.38433780236406, -32.93436955375282],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 3,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c146cc5b2af0ac9dcfc679fcb9b4a97b = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d436d77f679909e308e8f44394bb3934);
#
#
#             var marker_ece165a9290a60a7004d58e4bf90118c = L.marker(
#                 [35.662511423959494, 19.928860506771173],
#                 {}
#             ).addTo(map_d436d77f679909e308e8f44394bb3934);
#
#
#             var icon_6d09f3ea0e1b12f73561af390d8a3d0d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;map-marker&quot;, &quot;iconColor&quot;: &quot;green&quot;, &quot;markerColor&quot;: &quot;white&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_ece165a9290a60a7004d58e4bf90118c.setIcon(icon_6d09f3ea0e1b12f73561af390d8a3d0d);
#
#
#         var popup_a80b014336fe369086b202c26b82943c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e77a4ca2a652df0917d5235f4951aa4d = $(`&lt;div id=&quot;html_e77a4ca2a652df0917d5235f4951aa4d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cluster 0.0&lt;/div&gt;`)[0];
#                 popup_a80b014336fe369086b202c26b82943c.setContent(html_e77a4ca2a652df0917d5235f4951aa4d);
#
#
#
#         marker_ece165a9290a60a7004d58e4bf90118c.bindPopup(popup_a80b014336fe369086b202c26b82943c)
#         ;
#
#
#
#
#             var marker_971b179521bc2e2003853d68e7fabded = L.marker(
#                 [37.237176298315006, -95.39232199873494],
#                 {}
#             ).addTo(map_d436d77f679909e308e8f44394bb3934);
#
#
#             var icon_1bee92312bfde6ad9bd98c29d5701592 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;map-marker&quot;, &quot;iconColor&quot;: &quot;orange&quot;, &quot;markerColor&quot;: &quot;white&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_971b179521bc2e2003853d68e7fabded.setIcon(icon_1bee92312bfde6ad9bd98c29d5701592);
#
#
#         var popup_d9df2b1347a49201a527f03283339ee8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d4ff901496ac9f703f4ab6333b3b1ae4 = $(`&lt;div id=&quot;html_d4ff901496ac9f703f4ab6333b3b1ae4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cluster 1.0&lt;/div&gt;`)[0];
#                 popup_d9df2b1347a49201a527f03283339ee8.setContent(html_d4ff901496ac9f703f4ab6333b3b1ae4);
#
#
#
#         marker_971b179521bc2e2003853d68e7fabded.bindPopup(popup_d9df2b1347a49201a527f03283339ee8)
#         ;
#
#
#
#
#         function geo_json_d308e2ce659cbe6d027909ebca5717f4_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#
#         function geo_json_d308e2ce659cbe6d027909ebca5717f4_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_d308e2ce659cbe6d027909ebca5717f4 = L.geoJson(null, {
#                 onEachFeature: geo_json_d308e2ce659cbe6d027909ebca5717f4_onEachFeature,
#
#                 style: geo_json_d308e2ce659cbe6d027909ebca5717f4_styler,
#         });
#
#         function geo_json_d308e2ce659cbe6d027909ebca5717f4_add (data) {
#             geo_json_d308e2ce659cbe6d027909ebca5717f4
#                 .addData(data)
#                 .addTo(map_d436d77f679909e308e8f44394bb3934);
#         }
#             geo_json_d308e2ce659cbe6d027909ebca5717f4_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[146.004858962294, -42.53739339934529], [145.99505724826105, -42.53691187201251], [145.98534993009238, -42.535471927385615], [-37.69138816805406, -10.007743417218064], [-37.700907603577896, -10.005358922750961], [-37.71014747908896, -10.002052842428869], [-37.71901880953505, -9.997857015612576], [-37.72743615915441, -9.992811850407994], [-37.735318464268815, -9.986965934514014], [-37.74258981397111, -9.980375567296395], [-37.74918018118873, -9.973104217594106], [-37.75502609708270

# %% [markdown]
# ## 5. Perhitungan Haversine Formula 2 CLuster

# %%
centroids_data = {
    'Latitude': [left_centroid[0], right_centroid[0]],
    'Longitude': [left_centroid[1], right_centroid[1]]
}

centers_k2 = pd.DataFrame(centroids_data)
print(centers_k2)
# Out:
#    Latitude  Longitude
# 0      -0.0      -90.0
# 1      -0.0       90.0

# %%
print(centers_k2)
# Out:
#    Latitude  Longitude
# 0      -0.0      -90.0
# 1      -0.0       90.0

# %%
print(cluster_centers)
# Out:
#              Latitude  Longitude
# Cluster-K2
# 0.0         35.662511  19.928861
# 1.0         37.237176 -95.392322

# %%
import numpy as np
import pandas as pd

def haversine(lat1, lon1, lat2, lon2):
    lat1, lon1, lat2, lon2 = map(np.radians, [lat1, lon1, lat2, lon2])
    dlat = lat2 - lat1
    dlon = lon2 - lon1
    a = np.sin(dlat/2)**2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlon/2)**2
    c = 2 * np.arcsin(np.sqrt(a))
    r = 6371
    return c * r

distances = np.zeros((len(cluster_centers), len(centers_k2)))

for i in range(len(cluster_centers)):
    for j in range(len(centers_k2)):
        lat1, lon1 = cluster_centers.iloc[i]['Latitude'], cluster_centers.iloc[i]['Longitude']
        lat2, lon2 = centers_k2.iloc[j]['Latitude'], centers_k2.iloc[j]['Longitude']
        distances[i, j] = haversine(lat1, lon1, lat2, lon2)

distances_df = pd.DataFrame(distances, index=cluster_centers.index, columns=centers_k2.index)
print(distances_df)
# Out:
#                        0             1
# Cluster-K2
# 0.0         11795.239834   8219.846962
# 1.0          4177.539082  15837.547714

# %%
distances = []
for i in range(2):
    kmeans_lat, kmeans_lon = cluster_centers['Latitude'][i], cluster_centers['Longitude'][i]
    distance = np.sqrt((kmeans_lat - orig_lat)**2 + (kmeans_lon - orig_lon)**2)
    distances.append(distance)

distances_df = pd.DataFrame({'Distance': distances})
distances_df.index.name = 'Centroid'

print(distances_df)
# Out:
#            Distance
# Centroid
# 0         59.659279
# 1         52.044224

# %% [markdown]
# ## 6. Membuat Fungsi K-Means dan Menghitung Cluster Center dari 2 atau 3 cluster

# %%
world_geojson = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

map_center = [cluster_centers_K3['Latitude'].mean(), cluster_centers_K3['Longitude'].mean()]
my_map = folium.Map(location=map_center, zoom_start=3)

cluster_colors = {0: 'yellow', 1: 'orange', 2: 'red',}

folium.Choropleth(
    geo_data='world.json',
    name='choropleth',
    data=df,
    columns=['Country', 'Cluster-K3'],
    key_on='feature.properties.name',
    fill_color='YlOrRd',
    fill_opacity=0.8,
    line_opacity=0.5,
    nan_fill_color='white',
    nan_fill_opacity=0,
    legend_name='Cluster'
).add_to(my_map)

for idx, center in cluster_centers_K3.iterrows():
    cluster_color = cluster_colors[idx % len(cluster_colors)]
    icon = folium.Icon(color='white', icon_color=cluster_color, icon='map-marker', prefix='fa')
    folium.Marker(
        location=[center['Latitude'], center['Longitude']],
        icon=icon,
        popup=f'Cluster {idx}',
    ).add_to(my_map)

folium.LayerControl().add_to(my_map)

my_map
# Out:
# <ipython-input-15-075db6b5f7f5>:1: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world_geojson = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0731f9c01d5f2026b1945f03f0b29805 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0731f9c01d5f2026b1945f03f0b29805&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0731f9c01d5f2026b1945f03f0b29805 = L.map(
#                 &quot;map_0731f9c01d5f2026b1945f03f0b29805&quot;,
#                 {
#                     center: [18.96541542820206, 12.983355048357206],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 3,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2fd73e844778d972c9bb982214c958c1 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_0731f9c01d5f2026b1945f03f0b29805);
#
#
#             var choropleth_d4e105661cb5d69c79707585728c62c1 = L.featureGroup(
#                 {}
#             ).addTo(map_0731f9c01d5f2026b1945f03f0b29805);
#
#
#         function geo_json_35ff355b45b3d31efe1dd11c1cb14564_styler(feature) {
#             switch(feature.properties.name) {
#                 case &quot;Australia&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fd8d3c&quot;, &quot;fillOpacity&quot;: 0.8, &quot;opacity&quot;: 0.5, &quot;weight&quot;: 1};
#                 case &quot;Brazil&quot;: case &quot;Canada&quot;: case &quot;Mexico&quot;: case &quot;United States of America&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#bd0026&quot;, &quot;fillOpacity&quot;: 0.8, &quot;opacity&quot;: 0.5, &quot;weight&quot;: 1};
#                 case &quot;Germany&quot;: case &quot;Spain&quot;: case &quot;France&quot;: case &quot;United Kingdom&quot;: case &quot;Italy&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ffffb2&quot;, &quot;fillOpacity&quot;: 0.8, &quot;opacity&quot;: 0.5, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;white&quot;, &quot;fillOpacity&quot;: 0, &quot;opacity&quot;: 0.5, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_35ff355b45b3d31efe1dd11c1cb14564_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_35ff355b45b3d31efe1dd11c1cb14564 = L.geoJson(null, {
#                 onEachFeature: geo_json_35ff355b45b3d31efe1dd11c1cb14564_onEachFeature,
#
#                 style: geo_json_35ff355b45b3d31efe1dd11c1cb14564_styler,
#         });
#
#         function geo_json_35ff355b45b3d31efe1dd11c1cb14564_add (data) {
#             geo_json_35ff355b45b3d31efe1dd11c1cb14564
#                 .addData(data)
#                 .addTo(choropleth_d4e105661cb5d69c79707585728c62c1);
#         }
#             geo_json_35ff355b45b3d31efe1dd11c1cb14564_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[61.210817, 35.650072], [62.230651, 35.270664], [62.984662, 35.404041], [63.193538, 35.857166], [63.982896, 36.007957], [64.546479, 36.312073], [64.746105, 37.111818], [65.588948, 37.305217], [65.745631, 37.661164], [66.217385, 37.39379], [66.518607, 37.362784], [67.075782, 37.356144], [67.83, 37.144994], [68.135562, 37.023115], [68.859446, 37.344336], [69.196273, 37.151144], [69.518785, 37.608997], [70.116578, 37.588223], [70.270574, 37.735165], [70.376304, 38.138396], [70.806821, 38.486282], [71.348131, 38.258905], [71.239404, 37.953265], [71.541918, 37.905774], [71.448693, 37.065645], [71.844638, 36.738171], [72.193041, 36.948288], [72.63689, 37.047558], [73.260056, 37.495257], [73.948696, 37.421566], [74.980002, 37.41999], [75.158028, 37.133031], [74.575893, 37.020841], [74.067552, 36.836176], [72.920025, 36.720007], [71.846292, 36.509942], [71.262348, 36.074388], [71.498768, 35.650563], [71.613076, 35.153203], [71.115019, 34.733126], [71.156773, 34.348911], [70.881803, 33.988856], [69.930543, 34.02012], [70.323594, 33.358533], [69.687147, 33.105499], [69.262522, 32.501944], [69.317764, 31.901412], [68.926677, 31.620189], [68.556932, 31.71331], [67.792689, 31.58293], [67.683394, 31.303154], [66.938891, 31.304911], [66.381458, 30.738899], [66.346473, 29.887943], [65.046862, 29.472181], [64.350419, 29.560031], [64.148002, 29.340819], [63.550261, 29.468331], [62.549857, 29.318572], [60.874248, 29.829239], [61.781222, 30.73585], [61.699314, 31.379506], [60.941945, 31.548075], [60.863655, 32.18292], [60.536078, 32.981269], [60.9637, 33.528832], [60.52843, 33.676446], [60.803193, 34.404102], [61.210817, 35.650072]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;AFG&quot;, &quot;properties&quot;: {&quot;name&quot;: &q

# %%
world_geojson = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

map_center = [cluster_centers_K2['Latitude'].mean(), cluster_centers_K2['Longitude'].mean()]
my_map = folium.Map(location=map_center, zoom_start=3)

cluster_colors = {0: 'yellow', 1: 'orange', 2: 'red',}

folium.Choropleth(
    geo_data='world.json',
    name='choropleth',
    data=df,
    columns=['Country', 'Cluster-K3'],
    key_on='feature.properties.name',
    fill_color='YlOrRd',
    fill_opacity=0.8,
    line_opacity=0.5,
    nan_fill_color='white',
    nan_fill_opacity=0,
    legend_name='Cluster'
).add_to(my_map)

for idx, center in cluster_centers_K3.iterrows():
    cluster_color = cluster_colors[idx % len(cluster_colors)]
    icon = folium.Icon(color='white', icon_color=cluster_color, icon='map-marker', prefix='fa')
    folium.Marker(
        location=[center['Latitude'], center['Longitude']],
        icon=icon,
        popup=f'Cluster {idx}',
    ).add_to(my_map)

for i in range(len(cluster_centers_K3)):
    for j in range(i + 1, len(cluster_centers_K3)):
        point1 = cluster_centers_K3.iloc[i]
        point2 = cluster_centers_K3.iloc[j]
        folium.PolyLine(
            locations=[[point1['Latitude'], point1['Longitude']], [point2['Latitude'], point2['Longitude']]],
            color='black',
            weight=2,
            dash_array='5, 5'
        ).add_to(my_map)

folium.LayerControl().add_to(my_map)

my_map
# Out:
# <ipython-input-21-6c06826b007d>:1: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world_geojson = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_eb7e60adb0b93bf8e4b4e0f032112389 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_eb7e60adb0b93bf8e4b4e0f032112389&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_eb7e60adb0b93bf8e4b4e0f032112389 = L.map(
#                 &quot;map_eb7e60adb0b93bf8e4b4e0f032112389&quot;,
#                 {
#                     center: [36.449843861137225, -37.73173074598194],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 3,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f5578210b27435ca4df6ecc7159bc066 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_eb7e60adb0b93bf8e4b4e0f032112389);
#
#
#             var choropleth_e7a6c10a40c046300c06460904e0b810 = L.featureGroup(
#                 {}
#             ).addTo(map_eb7e60adb0b93bf8e4b4e0f032112389);
#
#
#         function geo_json_c6ed64b760557b9fc12bfbe4ab213c39_styler(feature) {
#             switch(feature.properties.name) {
#                 case &quot;Australia&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fd8d3c&quot;, &quot;fillOpacity&quot;: 0.8, &quot;opacity&quot;: 0.5, &quot;weight&quot;: 1};
#                 case &quot;Brazil&quot;: case &quot;Canada&quot;: case &quot;Mexico&quot;: case &quot;United States of America&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#bd0026&quot;, &quot;fillOpacity&quot;: 0.8, &quot;opacity&quot;: 0.5, &quot;weight&quot;: 1};
#                 case &quot;Germany&quot;: case &quot;Spain&quot;: case &quot;France&quot;: case &quot;United Kingdom&quot;: case &quot;Italy&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ffffb2&quot;, &quot;fillOpacity&quot;: 0.8, &quot;opacity&quot;: 0.5, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;white&quot;, &quot;fillOpacity&quot;: 0, &quot;opacity&quot;: 0.5, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_c6ed64b760557b9fc12bfbe4ab213c39_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_c6ed64b760557b9fc12bfbe4ab213c39 = L.geoJson(null, {
#                 onEachFeature: geo_json_c6ed64b760557b9fc12bfbe4ab213c39_onEachFeature,
#
#                 style: geo_json_c6ed64b760557b9fc12bfbe4ab213c39_styler,
#         });
#
#         function geo_json_c6ed64b760557b9fc12bfbe4ab213c39_add (data) {
#             geo_json_c6ed64b760557b9fc12bfbe4ab213c39
#                 .addData(data)
#                 .addTo(choropleth_e7a6c10a40c046300c06460904e0b810);
#         }
#             geo_json_c6ed64b760557b9fc12bfbe4ab213c39_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[61.210817, 35.650072], [62.230651, 35.270664], [62.984662, 35.404041], [63.193538, 35.857166], [63.982896, 36.007957], [64.546479, 36.312073], [64.746105, 37.111818], [65.588948, 37.305217], [65.745631, 37.661164], [66.217385, 37.39379], [66.518607, 37.362784], [67.075782, 37.356144], [67.83, 37.144994], [68.135562, 37.023115], [68.859446, 37.344336], [69.196273, 37.151144], [69.518785, 37.608997], [70.116578, 37.588223], [70.270574, 37.735165], [70.376304, 38.138396], [70.806821, 38.486282], [71.348131, 38.258905], [71.239404, 37.953265], [71.541918, 37.905774], [71.448693, 37.065645], [71.844638, 36.738171], [72.193041, 36.948288], [72.63689, 37.047558], [73.260056, 37.495257], [73.948696, 37.421566], [74.980002, 37.41999], [75.158028, 37.133031], [74.575893, 37.020841], [74.067552, 36.836176], [72.920025, 36.720007], [71.846292, 36.509942], [71.262348, 36.074388], [71.498768, 35.650563], [71.613076, 35.153203], [71.115019, 34.733126], [71.156773, 34.348911], [70.881803, 33.988856], [69.930543, 34.02012], [70.323594, 33.358533], [69.687147, 33.105499], [69.262522, 32.501944], [69.317764, 31.901412], [68.926677, 31.620189], [68.556932, 31.71331], [67.792689, 31.58293], [67.683394, 31.303154], [66.938891, 31.304911], [66.381458, 30.738899], [66.346473, 29.887943], [65.046862, 29.472181], [64.350419, 29.560031], [64.148002, 29.340819], [63.550261, 29.468331], [62.549857, 29.318572], [60.874248, 29.829239], [61.781222, 30.73585], [61.699314, 31.379506], [60.941945, 31.548075], [60.863655, 32.18292], [60.536078, 32.981269], [60.9637, 33.528832], [60.52843, 33.676446], [60.803193, 34.404102], [61.210817, 35.650072]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;AFG&quot;, &quot;properties&quot;: {&quot;name&quot;: &

# %%
for i in range(len(cluster_centers_K3)):
    for j in range(i + 1, len(cluster_centers_K3)):
        point1 = cluster_centers_K3.iloc[i]
        point2 = cluster_centers_K3.iloc[j]
        folium.PolyLine(
            locations=[[point1['Latitude'], point1['Longitude']], [point2['Latitude'], point2['Longitude']]],
            color='black',
            weight=2,
            dash_array='5, 5'
        ).add_to(my_map)

# %%
from shapely.geometry import MultiPoint, Point
import geopandas as gpd

cluster_polygons = []

for cluster_id, cluster_data in df.groupby('Cluster-K3'):
    points = MultiPoint(cluster_data[['Longitude', 'Latitude']].values)
    buffer = points.buffer(0.1)
    cluster_polygon = buffer.convex_hull
    cluster_polygons.append({'Cluster-K3': cluster_id, 'geometry': cluster_polygon})
cluster_polygons_gdf = gpd.GeoDataFrame(cluster_polygons)

cluster_polygons_gdf.set_crs(epsg=4326, inplace=True)

cluster_centers = df.groupby('Cluster-K3').agg({'Latitude': 'mean', 'Longitude': 'mean'})
map_center = [df['Latitude'].mean(), df['Longitude'].mean()]
my_map = folium.Map(location=map_center, zoom_start=3)
cluster_colors = {0: 'yellow', 1: 'orange', 2: 'red',}

for idx, center in cluster_centers_K3.iterrows():
    cluster_color = cluster_colors[idx % len(cluster_colors)]
    icon = folium.Icon(color='white', icon_color=cluster_color, icon='map-marker', prefix='fa')
    folium.Marker(
        location=[center['Latitude'], center['Longitude']],
        icon=icon,
        popup=f'Cluster {idx}',
    ).add_to(my_map)

for cluster_id, cluster_data in cluster_polygons_gdf.iterrows():
    cluster_color = cluster_colors[cluster_data['Cluster-K3']]
    folium.GeoJson(
        cluster_data['geometry'],
        style_function=lambda feature, color=cluster_color: {
            'fillColor': color,
            'color': 'black',
            'weight': 2,
            'fillOpacity': 0.5,
        }
    ).add_to(my_map)

for i in range(len(cluster_centers_K3)):
    for j in range(i + 1, len(cluster_centers_K3)):
        point1 = cluster_centers_K3.iloc[i]
        point2 = cluster_centers_K3.iloc[j]
        folium.PolyLine(
            locations=[[point1['Latitude'], point1['Longitude']], [point2['Latitude'], point2['Longitude']]],
            color='black',
            weight=2,
            dash_array='5, 5'
        ).add_to(my_map)

my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2e327fb83534ddfa57ab7b2a39c3a744 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2e327fb83534ddfa57ab7b2a39c3a744&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2e327fb83534ddfa57ab7b2a39c3a744 = L.map(
#                 &quot;map_2e327fb83534ddfa57ab7b2a39c3a744&quot;,
#                 {
#                     center: [36.38433780236406, -32.93436955375282],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 3,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_99c95a69079d4889868978ae16fad875 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_2e327fb83534ddfa57ab7b2a39c3a744);
#
#
#             var marker_31b3c615f59ea6b504a8dacde33bc9f5 = L.marker(
#                 [43.79531301727043, 0.8031318372329871],
#                 {}
#             ).addTo(map_2e327fb83534ddfa57ab7b2a39c3a744);
#
#
#             var icon_f4da1fe5d976aabb607d47651d8aeb14 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;map-marker&quot;, &quot;iconColor&quot;: &quot;yellow&quot;, &quot;markerColor&quot;: &quot;white&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_31b3c615f59ea6b504a8dacde33bc9f5.setIcon(icon_f4da1fe5d976aabb607d47651d8aeb14);
#
#
#         var popup_e3bfc2c9a9ecbf325f9b07804b5325a3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_88a79d0f956a6a7e78bd1084e031310d = $(`&lt;div id=&quot;html_88a79d0f956a6a7e78bd1084e031310d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cluster 0&lt;/div&gt;`)[0];
#                 popup_e3bfc2c9a9ecbf325f9b07804b5325a3.setContent(html_88a79d0f956a6a7e78bd1084e031310d);
#
#
#
#         marker_31b3c615f59ea6b504a8dacde33bc9f5.bindPopup(popup_e3bfc2c9a9ecbf325f9b07804b5325a3)
#         ;
#
#
#
#
#             var marker_10633d67933d970eefc01079b3e419e1 = L.marker(
#                 [-25.441349427115536, 135.01622209332223],
#                 {}
#             ).addTo(map_2e327fb83534ddfa57ab7b2a39c3a744);
#
#
#             var icon_a3869ae061c3f6d37e081b5e6eabcc73 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;map-marker&quot;, &quot;iconColor&quot;: &quot;orange&quot;, &quot;markerColor&quot;: &quot;white&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_10633d67933d970eefc01079b3e419e1.setIcon(icon_a3869ae061c3f6d37e081b5e6eabcc73);
#
#
#         var popup_6a6e546efdd0418607e3c8ed06459cfb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_31c56959307b43f98e4f6e706ef88d73 = $(`&lt;div id=&quot;html_31c56959307b43f98e4f6e706ef88d73&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cluster 1&lt;/div&gt;`)[0];
#                 popup_6a6e546efdd0418607e3c8ed06459cfb.setContent(html_31c56959307b43f98e4f6e706ef88d73);
#
#
#
#         marker_10633d67933d970eefc01079b3e419e1.bindPopup(popup_6a6e546efdd0418607e3c8ed06459cfb)
#         ;
#
#
#
#
#             var marker_e1cde79ebfde55186d4125a5384abac0 = L.marker(
#                 [38.54228269445129, -96.8692887854836],
#                 {}
#             ).addTo(map_2e327fb83534ddfa57ab7b2a39c3a744);
#
#
#             var icon_e64a48e1af064a12233c098b8dc93703 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;map-marker&quot;, &quot;iconColor&quot;: &quot;red&quot;, &quot;markerColor&quot;: &quot;white&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_e1cde79ebfde55186d4125a5384abac0.setIcon(icon_e64a48e1af064a12233c098b8dc93703);
#
#
#         var popup_f5af8292dc02c73e9420247029758b6c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_af9f8515bdbce4a88a342a5e1d1c43b8 = $(`&lt;div id=&quot;html_af9f8515bdbce4a88a342a5e1d1c43b8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cluster 2&lt;/div&gt;`)[0];
#                 popup_f5af8292dc02c73e9420247029758b6c.setContent(html_af9f8515bdbce4a88a342a5e1d1c43b8);
#
#
#
#         marker_e1cde79ebfde55186d4125a5384abac0.bindPopup(popup_f5af8292dc02c73e9420247029758b6c)
#         ;
#
#
#
#
#         function geo_json_77e9094a46340d5f3ff7369a46007c4f_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;yellow&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#
#         f

# %%
from shapely.geometry import MultiPoint, Point
import geopandas as gpd

cluster_polygons = []
for cluster_id, cluster_data in df.groupby('Cluster-K3'):
    points = MultiPoint(cluster_data[['Longitude', 'Latitude']].values)
    buffer = points.buffer(0.1)
    cluster_polygon = buffer.convex_hull
    cluster_polygons.append({'Cluster-K3': cluster_id, 'geometry': cluster_polygon})

cluster_polygons_gdf = gpd.GeoDataFrame(cluster_polygons)

cluster_polygons_gdf.set_crs(epsg=4326, inplace=True)

cluster_centers = df.groupby('Cluster-K3').agg({'Latitude': 'mean', 'Longitude': 'mean'})
map_center = [df['Latitude'].mean(), df['Longitude'].mean()]
my_map = folium.Map(location=map_center, zoom_start=3)

cluster_colors = {0: '#1f77b4', 1: '#ff7f0e', 2: '#2ca02c'}

for idx, row in df.iterrows():
    cluster_color = cluster_colors[row['Cluster-K3']]
    folium.CircleMarker(
        location=[row['Latitude'], row['Longitude']],
        radius=5,
        color='black',
        fill=True,
        fill_color=cluster_color,
        fill_opacity=0.8
    ).add_to(my_map)

for idx, center in cluster_centers_K3.iterrows():
    cluster_color = cluster_colors[idx % len(cluster_colors)]
    icon = folium.Icon(color='white', icon_color=cluster_color, icon='map-marker', prefix='fa')
    folium.Marker(
        location=[center['Latitude'], center['Longitude']],
        icon=icon,
        popup=f'Cluster {idx}',
    ).add_to(my_map)

for cluster_id, cluster_data in cluster_polygons_gdf.iterrows():
    cluster_color = cluster_colors[cluster_data['Cluster-K3']]
    folium.GeoJson(
        cluster_data['geometry'],
        style_function=lambda feature, color=cluster_color: {
            'fillColor': color,
            'color': 'black',
            'weight': 2,
            'fillOpacity': 0.5,
        }
    ).add_to(my_map)

my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_aeeb2dbb7d49045c50bff6029ad6f7da {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_aeeb2dbb7d49045c50bff6029ad6f7da&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_aeeb2dbb7d49045c50bff6029ad6f7da = L.map(
#                 &quot;map_aeeb2dbb7d49045c50bff6029ad6f7da&quot;,
#                 {
#                     center: [36.264347167055114, -33.56196718464052],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 3,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c5f5f2d0a028845c1f17a4b577801bdd = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_aeeb2dbb7d49045c50bff6029ad6f7da);
#
#
#             var circle_marker_b0e8c8216a2461fb93073f5fda4c39be = L.circleMarker(
#                 [39.7837304, -100.445882],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#2ca02c&quot;, &quot;fillOpacity&quot;: 0.8, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_aeeb2dbb7d49045c50bff6029ad6f7da);
#
#
#             var circle_marker_4339bf70164f76510bbb0588b7fb6f24 = L.circleMarker(
#                 [61.0666922, -107.991707],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#2ca02c&quot;, &quot;fillOpacity&quot;: 0.8, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_aeeb2dbb7d49045c50bff6029ad6f7da);
#
#
#             var circle_marker_ebae5238f762fdc3807540f652d82084 = L.circleMarker(
#                 [54.7023545, -3.2765753],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#1f77b4&quot;, &quot;fillOpacity&quot;: 0.8, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_aeeb2dbb7d49045c50bff6029ad6f7da);
#
#
#             var circle_marker_39641102d21411554d9188101fe8f0ba = L.circleMarker(
#                 [-24.7761086, 134.755],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#ff7f0e&quot;, &quot;fillOpacity&quot;: 0.8, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_aeeb2dbb7d49045c50bff6029ad6f7da);
#
#
#             var circle_marker_4608cc2b0e7bf3fd399da8ec8b82e450 = L.circleMarker(
#                 [51.1638175, 10.4478313],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#1f77b4&quot;, &quot;fillOpacity&quot;: 0.8, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_aeeb2dbb7d49045c50bff6029ad6f7da);
#
#
#             var circle_marker_10e778760cd56f6c8fa45baac6d4dddd = L.circleMarker(
#                 [46.603354, 1.8883335],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#1f77b4&quot;, &quot;fillOpacity&quot;: 0.8, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_aeeb2dbb7d49045c50bff6029ad6f7da);
#
#
#             var circle_marker_09dabb17b43b7046f822bc3b2

# %%
from shapely.geometry import Point, Polygon
import math

world_geojson = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

square_bounds = [-180, -90, 180, 90]
square_polygon = Polygon([
    (square_bounds[0], square_bounds[1]),
    (square_bounds[0], square_bounds[3]),
    (square_bounds[2], square_bounds[3]),
    (square_bounds[2], square_bounds[1]),
    (square_bounds[0], square_bounds[1])
])

center_lat = (square_bounds[1] + square_bounds[3]) / 2
center_lon = (square_bounds[0] + square_bounds[2]) / 2
center_point = (center_lat, center_lon)

def calculate_point(center, distance, angle):
    lat, lon = center
    lat_rad = math.radians(lat)
    lon_rad = math.radians(lon)
    angle_rad = math.radians(angle)
    distance_deg = distance / 111

    new_lat = lat + (distance_deg * math.cos(angle_rad))
    new_lon = lon + (distance_deg * math.sin(angle_rad)) / math.cos(lat_rad)

    return new_lat, new_lon

sectors = []
angles = [330, 90, 210]
distance = 20000

end_points = []

for angle in angles:
    point1 = calculate_point(center_point, distance, angle)
    point2 = calculate_point(center_point, distance, angle + 120)
    sectors.append(Polygon([center_point, point1, point2]))
    end_points.append(point1)
    end_points.append(point2)

sector_centroids = [sector.centroid.coords[0][::1] for sector in sectors]

my_map = folium.Map(location=[0, 0], zoom_start=2)

cluster_polygons = []

for cluster_id, cluster_data in df.groupby('Cluster-K3'):
    points = MultiPoint(cluster_data[['Longitude', 'Latitude']].values)
    buffer = points.buffer(0.1)
    cluster_polygon = buffer.convex_hull
    cluster_polygons.append({'Cluster-K3': cluster_id, 'geometry': cluster_polygon})

cluster_polygons_gdf = gpd.GeoDataFrame(cluster_polygons)

cluster_polygons_gdf.set_crs(epsg=4326, inplace=True)

cluster_centers = df.groupby('Cluster-K3').agg({'Latitude': 'mean', 'Longitude': 'mean'})
map_center = [df['Latitude'].mean(), df['Longitude'].mean()]

cluster_colors = {0: '#1f77b4', 1: '#2ca02c', 2: '#ff7f0e'}

for idx, center in cluster_centers_K3.iterrows():
    cluster_color = cluster_colors[idx % len(cluster_colors)]
    icon = folium.Icon(color='white', icon_color=cluster_color, icon='map-marker', prefix='fa')
    folium.Marker(
        location=[center['Latitude'], center['Longitude']],
        icon=icon,
        popup=f'Cluster {idx}',
    ).add_to(my_map)

for cluster_id, cluster_data in cluster_polygons_gdf.iterrows():
    cluster_color = cluster_colors[cluster_data['Cluster-K3']]
    folium.GeoJson(
        cluster_data['geometry'],
        style_function=lambda feature, color=cluster_color: {
            'fillColor': color,
            'color': 'black',
            'weight': 2,
            'fillOpacity': 0.5,
        }
    ).add_to(my_map)

folium.GeoJson(
    square_polygon,
    style_function=lambda feature: {
        'fillColor': 'transparent',
        'color': 'black',
        'weight': 2
    }
).add_to(my_map)

folium.Marker(
    location=center_point,
    icon=folium.Icon(color='black', icon='info-sign'),
    popup='Center Point'
).add_to(my_map)

for angle in angles:
    end_point = calculate_point(center_point, distance, angle)
    folium.PolyLine(
        locations=[center_point, end_point],
        color="black"
    ).add_to(my_map)
    end_points.append(end_point)

sector_colors = ['blue', 'green', 'orange']

for i, centroid in enumerate(sector_centroids):
    color = sector_colors[i % len(sector_colors)]
    label = f'Sector {i} Centroid'
    folium.Marker(
        location=centroid,
        icon=folium.Icon(color=color, icon='info-sign'),
        popup=label
    ).add_to(my_map)

for i, centroid in enumerate(sector_centroids):
    color = sector_colors[i % len(sector_colors)]
    label = f'Sector {i} Centroid'
    folium.Marker(
        location=centroid,
        icon=folium.Icon(color=color, icon='info-sign'),
        popup=label
    ).add_to(my_map)

    point1 = cluster_centers.iloc[i]
    folium.PolyLine(
        locations=[centroid, [point1['Latitude'], point1['Longitude']]],
        color='black',
        weight=2,
        dash_array='5, 5'
    ).add_to(my_map)

my_map
# Out:
# <ipython-input-21-34d9f547656e>:5: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world_geojson = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_09e3091eb042613a8f1a5615aeb81107 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_09e3091eb042613a8f1a5615aeb81107&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_09e3091eb042613a8f1a5615aeb81107 = L.map(
#                 &quot;map_09e3091eb042613a8f1a5615aeb81107&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_95e6f33f674539fa544f05d4528b6854 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_09e3091eb042613a8f1a5615aeb81107);
#
#
#             var marker_89fe5a3d62b7cbcd7c1fd29aa832fd14 = L.marker(
#                 [43.79531301727043, 0.8031318372329871],
#                 {}
#             ).addTo(map_09e3091eb042613a8f1a5615aeb81107);
#
#
#             var icon_492c7dd1216980b9a2dbceefc159c1ba = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;map-marker&quot;, &quot;iconColor&quot;: &quot;#1f77b4&quot;, &quot;markerColor&quot;: &quot;white&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_89fe5a3d62b7cbcd7c1fd29aa832fd14.setIcon(icon_492c7dd1216980b9a2dbceefc159c1ba);
#
#
#         var popup_b767b838daf92682bd6b81f67b72f76d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_93e4b8302fbc263cfaadeae271298ab1 = $(`&lt;div id=&quot;html_93e4b8302fbc263cfaadeae271298ab1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cluster 0&lt;/div&gt;`)[0];
#                 popup_b767b838daf92682bd6b81f67b72f76d.setContent(html_93e4b8302fbc263cfaadeae271298ab1);
#
#
#
#         marker_89fe5a3d62b7cbcd7c1fd29aa832fd14.bindPopup(popup_b767b838daf92682bd6b81f67b72f76d)
#         ;
#
#
#
#
#             var marker_0b47cd0f1edf6da8e2c376bc750b98e0 = L.marker(
#                 [-25.441349427115536, 135.01622209332223],
#                 {}
#             ).addTo(map_09e3091eb042613a8f1a5615aeb81107);
#
#
#             var icon_ae3f334d64338eaf6477fa4b0c081ed6 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;map-marker&quot;, &quot;iconColor&quot;: &quot;#2ca02c&quot;, &quot;markerColor&quot;: &quot;white&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_0b47cd0f1edf6da8e2c376bc750b98e0.setIcon(icon_ae3f334d64338eaf6477fa4b0c081ed6);
#
#
#         var popup_27bc559a219ef55f4a498f5e1d481587 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1629ce51a6589ab5edc884afe57e2108 = $(`&lt;div id=&quot;html_1629ce51a6589ab5edc884afe57e2108&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cluster 1&lt;/div&gt;`)[0];
#                 popup_27bc559a219ef55f4a498f5e1d481587.setContent(html_1629ce51a6589ab5edc884afe57e2108);
#
#
#
#         marker_0b47cd0f1edf6da8e2c376bc750b98e0.bindPopup(popup_27bc559a219ef55f4a498f5e1d481587)
#         ;
#
#
#
#
#             var marker_9f2e0a05391cc61ca47d72b9528acbfb = L.marker(
#                 [38.54228269445129, -96.8692887854836],
#                 {}
#             ).addTo(map_09e3091eb042613a8f1a5615aeb81107);
#
#
#             var icon_de3b03d88aae278de91bb53f2f7b6086 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;map-marker&quot;, &quot;iconColor&quot;: &quot;#ff7f0e&quot;, &quot;markerColor&quot;: &quot;white&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_9f2e0a05391cc61ca47d72b9528acbfb.setIcon(icon_de3b03d88aae278de91bb53f2f7b6086);
#
#
#         var popup_f6d4b0acaa0036aa80e910fc327ee25c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9f79714230a043849eb31957f497aa98 = $(`&lt;div id=&quot;html_9f79714230a043849eb31957f497aa98&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cluster 2&lt;/div&gt;`)[0];
#                 popup_f6d4b0acaa0036aa80e910fc327ee25c.setContent(html_9f79714230a043849eb31957f497aa98);
#
#
#
#         marker_9f2e0a05391cc61ca47d72b9528acbfb.bindPopup(popup_f6d4b0acaa0036aa80e910fc327ee25c)
#         ;
#
#
#
#
#         function geo_json_e5cd408c903a6e3ff3bb5d0ed93ab66e_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#1f77b4&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#
#         function geo_json_e5cd4

# %% [markdown]
# ## 7. Perhitungan Haversine Formula 2 CLuster

# %%
centers_data = {
    'Latitude': [],
    'Longitude': []
}

for i, centroid in enumerate(sector_centroids[:3]):
    lat, lon = centroid
    lat = round(lat, 5)
    lon = round(lon, 5)
    centers_data['Latitude'].append(lat)
    centers_data['Longitude'].append(lon)

centers = pd.DataFrame(centers_data)

# %%
print(cluster_centers)
# Out:
#              Latitude   Longitude
# Cluster-K3
# 0.0         43.795313    0.803132
# 1.0        -25.441349  135.016222
# 2.0         38.542283  -96.869289

# %%
print(centers)
# Out:
#    Latitude  Longitude
# 0  52.01354   30.03003
# 1 -52.01354   30.03003
# 2  -0.00000  -60.06006

# %%
import numpy as np
import pandas as pd

def haversine(lat1, lon1, lat2, lon2):
    lat1, lon1, lat2, lon2 = map(np.radians, [lat1, lon1, lat2, lon2])

    dlat = lat2 - lat1
    dlon = lon2 - lon1
    a = np.sin(dlat/2)**2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlon/2)**2
    c = 2 * np.arcsin(np.sqrt(a))
    r = 6371
    return c * r

distances = np.zeros((len(cluster_centers), len(centers)))

for i in range(len(cluster_centers)):
    for j in range(len(centers)):
        lat1, lon1 = cluster_centers.iloc[i]['Latitude'], cluster_centers.iloc[i]['Longitude']
        lat2, lon2 = centers.iloc[j]['Latitude'], centers.iloc[j]['Longitude']
        distances[i, j] = haversine(lat1, lon1, lat2, lon2)

distances_df = pd.DataFrame(distances, index=cluster_centers.index, columns=centers.index)
print(distances_df)
# Out:
#                        0             1             2
# Cluster-K3
# 0.0          2342.320120  11016.897286   7719.592133
# 1.0         13213.938900   8758.083507  16755.441223
# 2.0          8711.292408  15708.756520   5696.354810

# %%
distances = []
for i in range(3):
    kmeans_lat, kmeans_lon = cluster_centers['Latitude'][i], cluster_centers['Longitude'][i]
    orig_lat, orig_lon = centers['Latitude'][i], centers['Longitude'][i]
    distance = np.sqrt((kmeans_lat - orig_lat)**2 + (kmeans_lon - orig_lon)**2)
    distances.append(distance)

distances_df = pd.DataFrame({'Distance': distances})
distances_df.index.name = 'Centroid'

print(distances_df)
# Out:
#             Distance
# Centroid
# 0          35.575820
# 1         107.912633
# 2          61.307521
